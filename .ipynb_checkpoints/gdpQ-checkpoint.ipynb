# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
gdpQ_file = "resources/t10101q.csv"
gdpQ_df = pd.read_csv(gdpQ_file)
gdpQ_df.head()
# Out:
#                               Factor   1930   1931   1932  1933  1934 1935  \
# 0             Gross domestic product   -8.5   -6.4  -12.9  -1.2  10.8  8.9
# 1  Personal consumption expenditures   -5.4   -3.1     -9  -2.2   7.1  6.1
# 2                              Goods   -7.9   -3.6  -11.7  -0.7   9.1  8.1
# 3                      Durable goods  -17.2  -13.6    -24  -2.6  14.4   21
# 4                   Nondurable goods   -5.2   -1.1   -8.8  -0.4   8.2  5.7
#
#    1936 1937   1938  ...  2009 2010 2011 2012 2013 2014 2015 2016 2017 2018
# 0  12.9  5.1   -3.3  ...  -2.5  2.6  1.6  2.2  1.8  2.5  2.9  1.6  2.2  2.9
# 1  10.2  3.7   -1.6  ...  -1.3  1.7  1.9  1.5  1.5  2.9  3.7  2.7  2.5  2.6
# 2  13.3    3   -2.2  ...  -3.1  2.8  2.2  2.1  3.1    4  4.7  3.6  3.7  3.7
# 3  22.2  5.2  -17.1  ...  -6.1  5.6  5.1    6  6.1  7.2  7.6  5.5  6.8  5.5
# 4  11.4  2.5    1.4  ...  -1.7  1.6  0.9  0.4  1.8  2.6  3.4  2.7  2.1  2.8
#
# [5 rows x 90 columns]

# %%
gdpQT_df =gdpQ_df.set_index('Factor').T
gdpQT_df.head()
# Out:
# Factor     Gross domestic product Personal consumption expenditures   Goods  \
# 1930                         -8.5                              -5.4    -7.9
# 1931                         -6.4                              -3.1    -3.6
# 1932                        -12.9                                -9   -11.7
# 1933                         -1.2                              -2.2    -0.7
# 1934                         10.8                               7.1     9.1
#
# Factor     Durable goods     Nondurable goods   Services  \
# 1930               -17.2                 -5.2       -2.1
# 1931               -13.6                 -1.1       -2.5
# 1932                 -24                 -8.8         -6
# 1933                -2.6                 -0.4       -3.7
# 1934                14.4                  8.2        4.9
#
# Factor Gross private domestic investment   Fixed investment  \
# 1930                               -31.9              -22.3
# ...

# %%
#Clean DataFrame
#gdpAT_df=gdpAT_df.drop('Abbrev',index[2])
#gdpAT_df

# %%
#Clean DataFrame
#new_gdpA_df.drop(new_gdpA_df.index[2])
#new_gdpA_df.head()

# %%
#gdpAT_df=gdpAT_df.rename(columns={'Factor':'Year'})
#gdpAT_df.head()

# %%
gdpQT_df.columns.name="Year"
gdpQT_df.head()
# Out:
# Year     Gross domestic product Personal consumption expenditures   Goods  \
# 1930                       -8.5                              -5.4    -7.9
# 1931                       -6.4                              -3.1    -3.6
# 1932                      -12.9                                -9   -11.7
# 1933                       -1.2                              -2.2    -0.7
# 1934                       10.8                               7.1     9.1
#
# Year     Durable goods     Nondurable goods   Services  \
# 1930             -17.2                 -5.2       -2.1
# 1931             -13.6                 -1.1       -2.5
# 1932               -24                 -8.8         -6
# 1933              -2.6                 -0.4       -3.7
# 1934              14.4                  8.2        4.9
#
# Year Gross private domestic investment   Fixed investment     Nonresidential  \
# 1930                             -31.9              -22.3              -16.7
# ...

# %%
#gdpAT_df=gdpAT_df.reset_index().rename(columns={'index':'Year'})
#gdpAT_df.head()
# Out:
# Factor  Year     Gross domestic product Personal consumption expenditures  \
# 0       1930                       -8.5                              -5.4
# 1       1931                       -6.4                              -3.1
# 2       1932                      -12.9                                -9
# 3       1933                       -1.2                              -2.2
# 4       1934                       10.8                               7.1
#
# Factor   Goods     Durable goods     Nondurable goods   Services  \
# 0         -7.9             -17.2                 -5.2       -2.1
# 1         -3.6             -13.6                 -1.1       -2.5
# 2        -11.7               -24                 -8.8         -6
# 3         -0.7              -2.6                 -0.4       -3.7
# 4          9.1              14.4                  8.2        4.9
#
# Factor Gross private domestic investment   Fixed investment  \
# 0                                  -31.9              -22.3
# ...

# %%
gdpAT_df.set_index('Year', inplace=True)
new_gdpAT_df=gdpAT_df.rename_axis(None)
new_gdpAT_df.head()
# Out:
# Factor     Gross domestic product Personal consumption expenditures   Goods  \
# 1930                         -8.5                              -5.4    -7.9
# 1931                         -6.4                              -3.1    -3.6
# 1932                        -12.9                                -9   -11.7
# 1933                         -1.2                              -2.2    -0.7
# 1934                         10.8                               7.1     9.1
#
# Factor     Durable goods     Nondurable goods   Services  \
# 1930               -17.2                 -5.2       -2.1
# 1931               -13.6                 -1.1       -2.5
# 1932                 -24                 -8.8         -6
# 1933                -2.6                 -0.4       -3.7
# 1934                14.4                  8.2        4.9
#
# Factor Gross private domestic investment   Fixed investment  \
# 1930                               -31.9              -22.3
# ...

# %%
gdpA_cols=[]
gdpA_transformed=gdpAT_df =gdpA_df[gdpA_cols].copy()
gdpA_transformed.head()
